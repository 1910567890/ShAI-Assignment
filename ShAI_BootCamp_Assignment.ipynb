# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# # Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv(r'C:\Users\HELLo\Downloads\Salaries.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.set_index("Id",inplace =True)
df.head()
# Out:
#          EmployeeName                                        JobTitle  \
# Id
# 1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# Id
# 1   167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 2   155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 3   212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 4    77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 5   134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#     Year  Notes         Agency  Status
# Id
# ...

# %%
print("Number of Rows {}".format(df.shape[0]))
print("Number of Columns {}".format(df.shape[1]))
# Out:
# Number of Rows 148654
# Number of Columns 12

# %%
df.dtypes
# Out:
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
df.isna().sum()
# Out:
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
#TASK2
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448841    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year  Notes  Status
# count  148654.000000     148654.000000  148654.000000    0.0     0.0
# mean    74768.321972      93692.554811    2012.522643    NaN     NaN
# std     50517.005274      62793.533483       1.117538    NaN     NaN
# min      -618.130000       -618.130000    2011.000000    NaN     NaN
# ...

# %%
# We drop two columns notes ,status because have many missing values and not impact to may data to replace this values 
df.drop(columns=['Notes','Status'],inplace =True)

# %%
# because some emloyee have nor benfits and this is normal
df['Benefits'].fillna(0, inplace=True)
df.head()
# Out:
#          EmployeeName                                        JobTitle  \
# Id
# 1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# Id
# 1   167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 2   155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 3   212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 4    77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 5   134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#     Year         Agency
# Id
# 1   2011  San Francisco
# ...

# %%
# We drop rows that have not basepay
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
df['TotalPayBenefits'].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.pie(df['JobTitle'].value_counts() )
plt.show()

# %%
df.head()
# Out:
#          EmployeeName                                        JobTitle  \
# Id
# 1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#       BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# Id
# 1   167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 2   155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 3   212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 4    77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 5   134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#     Year         Agency
# Id
# 1   2011  San Francisco
# ...

# %%
df.groupby('JobTitle').agg({'TotalPayBenefits': ['mean', 'median', 'min', 'max', 'std', 'count']})
# Out:
#                                                TotalPayBenefits             \
#                                                            mean     median
# JobTitle
# ACCOUNT CLERK                                      44035.664337  49777.820
# ACCOUNTANT                                         47429.268000  60076.240
# ACCOUNTANT INTERN                                  29031.742917  17658.505
# ACPO,JuvP, Juv Prob (SFERS)                        80266.370000  80266.370
# ACUPUNCTURIST                                      67594.400000  67594.400
# ...                                                         ...        ...
# X-RAY LABORATORY AIDE                              52705.880385  60333.125
# X-Ray Laboratory Aide                              69521.123200  85551.190
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS     53632.870000  53632.870
# Youth Comm Advisor                                 60118.550000  64871.285
# ...

# %%
plt.scatter(df['TotalPayBenefits'],df['BasePay'])
## positive correlation between TotalPayBenefits and basePay

# %% [markdown]
# Insights:
#
# The analysis suggests that there is a significant disparity in average salaries between ZOO CURATOR and ACCOUNTANT.
# ZOO CURATOR tends to have higher average salaries compared to ACCOUNTANT, as evidenced by both summary statistics .
# there are strong relation between TotalPayBenefits and basePay.
# and most employee works transint operator.
# Further investigation may be warranted to understand the factors contributing to the disparity in salaries between job position.

# %% [markdown]
# # Good Luck!
